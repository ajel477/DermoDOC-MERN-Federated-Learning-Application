# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import classification_report, confusion_matrix

# ==========================
# PATHS
# ==========================
train_dir = "/kaggle/input/datasets/takeoff012/skin-infection/train"
test_dir = "/kaggle/input/datasets/takeoff012/skin-infection/test"
model_save_path = "/kaggle/working/best_cnn_model.h5"

# ==========================
# PARAMETERS
# ==========================
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 30

# ==========================
# DATA GENERATORS
# ==========================
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

num_classes = len(train_generator.class_indices)

# ==========================
# MODEL
# ==========================
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(256, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=Adam(1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ==========================
# CALLBACKS
# ==========================
callbacks = [
    EarlyStopping(patience=6, restore_best_weights=True),
    ReduceLROnPlateau(patience=3, factor=0.3),
    ModelCheckpoint(model_save_path, save_best_only=True)
]

# ==========================
# TRAIN
# ==========================
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=callbacks
)

# ==========================
# EVALUATION
# ==========================
test_loss, test_acc = model.evaluate(test_generator)
print("Test Accuracy:", test_acc)

predictions = model.predict(test_generator)
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - CNN")
plt.show()

model.save("/kaggle/working/final_cnn_model.h5")
print("CNN Model Saved to /kaggle/working/")
# Out:
# 2026-03-02 06:54:19.438651: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772434459.775821      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772434459.883117      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772434460.718873      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772434460.718927      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772434460.718930      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772434460.718933      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 17379 images belonging to 10 classes.
# Found 4340 images belonging to 10 classes.
# Found 5434 images belonging to 10 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1772434512.828559      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772434519.395538     143 service.cc:152] XLA service 0x7de614015930 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1772434519.395578     143 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1772434520.116840     143 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   1/544 ━━━━━━━━━━━━━━━━━━━━ 1:37:08 11s/step - accuracy: 0.1875 - loss: 3.5580
# I0000 00:00:1772434526.648946     143 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - accuracy: 0.4588 - loss: 1.9622
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 436s 782ms/step - accuracy: 0.4589 - loss: 1.9614 - val_accuracy: 0.2749 - val_loss: 3.0243 - learning_rate: 1.0000e-04
# Epoch 2/30
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.5375 - loss: 1.2759
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 306s 563ms/step - accuracy: 0.5375 - loss: 1.2758 - val_accuracy: 0.3594 - val_loss: 2.1330 - learning_rate: 1.0000e-04
# Epoch 3/30
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.5584 - loss: 1.1579
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 303s 558ms/step - accuracy: 0.5584 - loss: 1.1579 - val_accuracy: 0.3150 - val_loss: 2.0327 - learning_rate: 1.0000e-04
# Epoch 4/30
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 304s 559ms/step - accuracy: 0.5654 - loss: 1.1150 - val_accuracy: 0.3880 - val_loss: 2.0705 - learning_rate: 1.0000e-04
# Epoch 5/30
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 303s 556ms/step - accuracy: 0.5767 - loss: 1.0669 - val_accuracy: 0.3843 - val_loss: 2.3872 - learning_rate: 1.0000e-04
# Epoch 6/30
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.5901 - loss: 1.0229
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 303s 557ms/step - accuracy: 0.5901 - loss: 1.0229 - val_accuracy: 0.4180 - val_loss: 1.9091 - learning_rate: 1.0000e-04
# Epoch 7/30
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 305s 560ms/step - accuracy: 0.6001 - loss: 0.9949 - val_accuracy: 0.3585 - val_loss: 2.5995 - learning_rate: 1.0000e-04
# Epoch 8/30
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 306s 562ms/step - accuracy: 0.6130 - loss: 0.9611 - val_accuracy: 0.4058 - val_loss: 2.4973 - learning_rate: 1.0000e-04
# Epoch 9/30
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 301s 554ms/step - accuracy: 0.6159 - loss: 0.9589 - val_accuracy: 0.4219 - val_loss: 2.0836 - learning_rate: 1.0000e-04
# Epoch 10/30
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 300s 551ms/step - accuracy: 0.6305 - loss: 0.8933 - val_accuracy: 0.4544 - val_loss: 2.3538 - learning_rate: 3.0000e-05
# Epoch 11/30
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 299s 549ms/step - accuracy: 0.6528 - loss: 0.8429 - val_accuracy: 0.4233 - val_loss: 2.4230 - learning_rate: 3.0000e-05
# Epoch 12/30
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 304s 560ms/step - accuracy: 0.6500 - loss: 0.8329 - val_accuracy: 0.4385 - val_loss: 2.6248 - learning_rate: 3.0000e-05
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 65s 386ms/step - accuracy: 0.4614 - loss: 1.3174
# Test Accuracy: 0.572690486907959
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 30s 170ms/step
#
# Classification Report:
#
#                                                                   precision    recall  f1-score   support
#
#                                                   1. Eczema 1677       0.32      0.02      0.03       336
#            10. Warts Molluscum and other Viral Infections - 2103       0.31      0.36      0.33       421
#                                               2. Melanoma 15.75k       0.79      0.76      0.77       628
#                                     3. Atopic Dermatitis - 1.25k       0.36      0.13      0.19       252
#                               4. Basal Cell Carcinoma (BCC) 3323       0.76      0.64      0.69       665
#                                  5. Melanocytic Nevi (NV) - 7970       0.83      0.85      0.84      1594
#                      6. Benign Keratosis-like Lesions (BKL) 2624       0.45      0.43      0.44       416
#    7. Psoriasis pictures Lichen Planus and related diseases - 2k       0.24      0.71      0.36       411
#           8. Seborrheic Keratoses and other Benign Tumors - 1.8k       0.45      0.44      0.44       370
# 9. Tinea Ringworm Candidiasis and other Fungal Infections - 1.7k       0.48      0.11      0.17       341
#
#                                                         accuracy                           0.57      5434
#                                                        macro avg       0.50      0.44      0.43      5434
#                                                     weighted avg       0.60      0.57      0.56      5434
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# CNN Model Saved to /kaggle/working/
